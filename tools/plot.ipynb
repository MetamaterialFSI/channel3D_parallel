# %%
import sys
sys.path.append('/resnick/groups/bae-group/ctlin/channel_IBPM/channel3D_parallel/tools')
from file_io import read_field

# %%
filename = "/resnick/groups/bae-group/ctlin/channel_IBPM/channel3D_parallel/examples/channel_output_ib_planar_wall/test.0"
data = read_field(filename)
globals().update(data)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
for grid_i in range(len(x)):
    for grid_k in range(len(z)+1):
        ax.plot(Hv_exterior[grid_i,:,grid_k], y, '-o')
fig, ax = plt.subplots()
grid_i = 4
for grid_j in range(len(y)):
    ax.plot(zg, Hv_exterior[grid_i,grid_j,:], '-o')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
for grid_i in range(len(x)):
    for grid_k in range(len(z)):
        ax.plot(Hw_exterior[grid_i,:,grid_k], yg, '-o')
fig, ax = plt.subplots()
grid_i = 4
for grid_j in range(len(yg)):
    ax.plot(z, Hw_exterior[grid_i,grid_j,:], '-o')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
for grid_i in range(len(x)):
    for grid_k in range(len(z)+1):
        ax.plot(Hv_exterior[grid_i,:,grid_k], y, '-o')
fig, ax = plt.subplots()
grid_i = 4
for grid_j in range(len(y)):
    ax.plot(zg, Hv_exterior[grid_i,grid_j,:], '-o')
